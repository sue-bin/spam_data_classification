# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

# %%
import numpy as np

# %%
train_df = pd.read_csv("/content/drive/My Drive/데이터분석/spam data/spam_data_train.csv")

# %%
train_df.head(15)
# Out:
#     Unnamed: 0    v1  ... Unnamed: 3 Unnamed: 4
# 0            0   ham  ...        NaN        NaN
# 1            1   ham  ...        NaN        NaN
# 2            2  spam  ...        NaN        NaN
# 3            3   ham  ...        NaN        NaN
# 4            4   ham  ...        NaN        NaN
# 5            5  spam  ...        NaN        NaN
# 6            6   ham  ...        NaN        NaN
# 7            7   ham  ...        NaN        NaN
# 8            8  spam  ...        NaN        NaN
# 9            9  spam  ...        NaN        NaN
# 10          10   ham  ...        NaN        NaN
# 11          11  spam  ...        NaN        NaN
# 12          12  spam  ...        NaN        NaN
# 13          13   ham  ...        NaN        NaN
# 14          14   ham  ...        NaN        NaN
#
# [15 rows x 6 columns]

# %%
train_df.isnull().sum()/len(train_df)
# Out:
# Unnamed: 0    0.000
# v1            0.000
# v2            0.000
# Unnamed: 2    0.991
# Unnamed: 3    0.998
# Unnamed: 4    0.999
# dtype: float64

# %%
del train_df["Unnamed: 2"]

# %%
del train_df["Unnamed: 3"]
del train_df["Unnamed: 4"]

# %%
train_df.isnull().sum()/len(train_df)
# Out:
# Unnamed: 0    0.0
# v1            0.0
# v2            0.0
# dtype: float64

# %%
train_df.head()
# Out:
#    Unnamed: 0    v1                                                 v2
# 0           0   ham  Go until jurong point, crazy.. Available only ...
# 1           1   ham                      Ok lar... Joking wif u oni...
# 2           2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           3   ham  U dun say so early hor... U c already then say...
# 4           4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize, WordPunctTokenizer

# %%
train_df.dtypes
# Out:
# Unnamed: 0     int64
# v1            object
# v2            object
# dtype: object

# %%
train_df["v2"] = train_df['v2'].astype(str)

# %%
text_list = train_df["v2"].tolist()

# %%
text_list[1]
# Out:
# 'Ok lar... Joking wif u oni...'

# %%
for i in np.arange(len(train_df)):
    train_df["v2"][i] = word_tokenize(text_list[i])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_df
# Out:
#       Unnamed: 0    v1                                                 v2
# 0              0   ham  [Go, until, jurong, point, ,, crazy.., Availab...
# 1              1   ham           [Ok, lar, ..., Joking, wif, u, oni, ...]
# 2              2  spam  [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 3              3   ham  [U, dun, say, so, early, hor, ..., U, c, alrea...
# 4              4   ham  [Nah, I, do, n't, think, he, goes, to, usf, ,,...
# ...          ...   ...                                                ...
# 4995        4995   ham  [Happy, new, year, ., Hope, you, are, having, ...
# 4996        4996   ham              [Esplanade, lor, ., Where, else, ...]
# 4997        4997   ham                       [Can, you, talk, with, me..]
# 4998        4998   ham             [Hmph, ., Go, head, ,, big, baller, .]
# 4999        4999   ham  [Well, its, not, like, you, actually, called, ...
#
# [5000 rows x 3 columns]

# %%
k = 0
for i in range(len(train_df)):
  j = len(train_df["v2"][i])
  if j > k:
    k = j

print(k)
# Out:
# 219

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences=train_df["v2"], size=10, window=6, workers=4, sg=1)

# %%
model_result1 = model.wv.most_similar("today")
print(model_result1)
# Out:
# [('dog', 0.9782664179801941), ('lesson', 0.9780027866363525), ('look', 0.9750574827194214), ('alone', 0.9741628170013428), ('Later', 0.9724671840667725), ('havent', 0.9723289608955383), ('Fuck', 0.9716273546218872), ('bout', 0.9714466333389282), ('Not', 0.9703257083892822), ('sun', 0.9702606797218323)]
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
model_result2 = model.wv.most_similar("happy")
print(model_result2)
# Out:
# [('well', 0.9869800806045532), ('fine', 0.985191822052002), ('always', 0.9841876029968262), ('all', 0.9751157164573669), ('evening', 0.9724770784378052), ('last', 0.9723151326179504), ('hope', 0.9713504910469055), ('Love', 0.9690346717834473), ('because', 0.9672114253044128), ('enough', 0.9667617678642273)]
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
model_result3 = model.wv.most_similar("man")
print(model_result3)
# Out:
# [('since', 0.9841734170913696), ('mu', 0.9804974794387817), ('says', 0.9794544577598572), ('til', 0.9784325957298279), ('old', 0.9782060384750366), ('pay', 0.9747663140296936), ('around', 0.9723513126373291), ('had', 0.9718003869056702), ('sent', 0.9681267738342285), ('In', 0.9657589793205261)]
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
